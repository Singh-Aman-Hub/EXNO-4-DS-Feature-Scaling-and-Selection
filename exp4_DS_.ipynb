# %% [markdown]
# <a href="https://colab.research.google.com/github/Singh-Aman-Hub/EXNO-4-DS-Feature-Scaling-and-Selection/blob/main/exp4_DS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy import stats
import numpy as np
df=pd.read_csv("/content/bmi.csv")
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df.dropna()
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
max_val=np.max(np.abs(df[['Height','Weight']]))
max_val
# Out:
# 199

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df[['Height','Weight']]=sc.fit_transform(df[['Height','Weight']])
df.head(10)
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.247939 -0.309117      4
# 1    Male  1.164872 -0.587322      2
# 2  Female  0.920357  0.123647      4
# 3  Female  1.531645 -0.061823      3
# 4    Male -1.280283 -1.391027      3
# 5    Male  1.164872 -0.061823      3
# 6    Male -1.402541 -0.432764      5
# 7    Male -0.974639  0.154559      5
# 8    Male  0.247939 -0.494587      3
# 9  Female -0.057706 -0.092735      4

# %%
from sklearn.preprocessing import Normalizer
nm=Normalizer()
df[['Height','Weight']]=nm.fit_transform(df[['Height','Weight']])
df
# Out:
#      Gender    Height    Weight  Index
# 0      Male  0.625687 -0.780074      4
# 1      Male  0.892924 -0.450208      2
# 2    Female  0.991096  0.133150      4
# 3    Female  0.999186 -0.040331      3
# 4      Male -0.677211 -0.735789      3
# ..      ...       ...       ...    ...
# 495  Female -0.642809  0.766027      5
# 496  Female  0.880037  0.474905      4
# 497  Female -0.885715  0.464230      5
# 498    Male -0.963237 -0.268652      5
# 499    Male  0.234966  0.972004      5
#
# [500 rows x 4 columns]

# %%
from sklearn.preprocessing import MaxAbsScaler
mas=MaxAbsScaler()
df[['Height','Weight']]=mas.fit_transform(df[['Height','Weight']])
df
# Out:
#      Gender    Height    Weight  Index
# 0      Male  0.625687 -0.780076      4
# 1      Male  0.892924 -0.450208      2
# 2    Female  0.991096  0.133151      4
# 3    Female  0.999186 -0.040331      3
# 4      Male -0.677211 -0.735791      3
# ..      ...       ...       ...    ...
# 495  Female -0.642809  0.766028      5
# 496  Female  0.880037  0.474906      4
# 497  Female -0.885715  0.464231      5
# 498    Male -0.963237 -0.268653      5
# 499    Male  0.234966  0.972006      5
#
# [500 rows x 4 columns]

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
df[['Height','Weight']]=rs.fit_transform(df[['Height','Weight']])
df.head(5)
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.424981 -0.547316      4
# 1    Male  0.617291 -0.315875      2
# 2  Female  0.687937  0.093421      4
# 3  Female  0.693760 -0.028297      3
# 4    Male -0.512615 -0.516245      3

# %%
from scipy.stats import chi2_contingency
import seaborn as sns
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
contingency_table=pd.crosstab(tips['sex'],tips['time'])
contingency_table
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     35      52

# %%
chi2,p,_,_=chi2_contingency(contingency_table)
print('Chi-square statistic:',chi2)
print('p-value:',p)
# Out:
# Chi-square statistic: 9.343808982970623
# p-value: 0.002237400118075248

# %%
from sklearn.feature_selection import SelectKBest,mutual_info_classif,f_classif
data={'Feature1' : [1,2,3,4,5],'Feature2' : ['A','B','C','A','B'],'Feature3' : [0,1,1,0,1],'Target': [0,1,1,0,1]}
df=pd.DataFrame(data)
df
# Out:
#    Feature1 Feature2  Feature3  Target
# 0         1        A         0       0
# 1         2        B         1       1
# 2         3        C         1       1
# 3         4        A         0       0
# 4         5        B         1       1

# %%
x=df[['Feature1','Feature3']]
y=df['Target']
selector=SelectKBest(score_func=mutual_info_classif,k=1)
x_new=selector.fit_transform(x,y)
print('Selected features:',x_new)
# Out:
# Selected features: [[0]
#  [1]
#  [1]
#  [0]
#  [1]]

# %%
selectedFeatureIndices=selector.get_support(indices=True)
selectedFeatures=x.columns[selectedFeatureIndices]
print('Selected features:',selectedFeatures)
# Out:
# Selected features: Index(['Feature3'], dtype='object')
